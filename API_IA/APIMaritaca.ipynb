# %% [markdown]
# # Maritaca AI

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - A MariTalk API possibilita que você os modelos Sabiá pagando um valor proporcional à quantidade de tokens enviados (prompt) e gerados.
#
# - Devido ao treinamento especializado dos modelos Sabiá, eles entregam uma qualidade maior a um menor preço do que os concorrentes.
#
# - Compare abaixo a qualidade dos modelos, medida pelo desempenho em 64 Exames Brasileiros (Enem, Enade, Revalida, OAB, UNICAMP, USP, etc) vs preço:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Veja a seguir o passo a passo para utilizar a API da Maritaca AI

# %% [markdown]
# #### Passo 1: Instalar bibliotecas

# %%
#!pip install maritalk

# %% [markdown]
# #### Passo 2: Importar bibliotecas

# %%
import maritalk
import json

# %% [markdown]
# #### Passo 3: Criar uma chave para a API

# %%
model = maritalk.MariTalk(key="copie sua chave aqui", model="sabia-3")

# %% [markdown]
# #### Passo 4: Configurar entrada

# %%
input_message = "Explique, resumidamente, quais são os critérios de Inovação"

# %% [markdown]
# #### Passo 5: Obter resposta da Maritalk

# %%
output_message = model.generate(input_message)
output_message
# Out:
# {'answer': 'Os critérios de inovação podem variar dependendo do contexto, da indústria e do tipo de inovação em questão, mas de maneira geral, eles incluem aspectos que definem se uma ideia, produto, serviço ou processo pode ser considerado inovador. Aqui estão alguns dos critérios comuns:\n\n1. **Novidade**: A inovação deve trazer algo novo, seja para o mercado, para a empresa ou para o setor em questão. Pode ser uma nova funcionalidade, um novo método de produção ou uma nova abordagem para resolver um problema.\n\n2. **Utilidade**: A inovação precisa ser útil e ter um propósito claro. Deve resolver um problema ou atender a uma necessidade que ainda não foi completamente satisfeita.\n\n3. **Implementabilidade**: A ideia inovadora deve ser viável e passível de ser implementada na prática, seja tecnicamente ou economicamente.\n\n4. **Valor Agregado**: Deve haver um benefício significativo em relação às alternativas existentes, seja em termos de eficiência, custo, desempenho ou experiê
# ...

# %% [markdown]
# #### Passo 6: Formatar Respostas

# %%
print(output_message["answer"])
# Out:
# Os critérios de inovação podem variar dependendo do contexto, da indústria e do tipo de inovação em questão, mas de maneira geral, eles incluem aspectos que definem se uma ideia, produto, serviço ou processo pode ser considerado inovador. Aqui estão alguns dos critérios comuns:
#
# 1. **Novidade**: A inovação deve trazer algo novo, seja para o mercado, para a empresa ou para o setor em questão. Pode ser uma nova funcionalidade, um novo método de produção ou uma nova abordagem para resolver um problema.
#
# 2. **Utilidade**: A inovação precisa ser útil e ter um propósito claro. Deve resolver um problema ou atender a uma necessidade que ainda não foi completamente satisfeita.
#
# 3. **Implementabilidade**: A ideia inovadora deve ser viável e passível de ser implementada na prática, seja tecnicamente ou economicamente.
#
# ...
